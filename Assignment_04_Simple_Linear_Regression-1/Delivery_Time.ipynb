# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Importing Data Files

# %%
df = pd.read_csv("delivery_time.csv")

# %%
X = df.iloc[:,0].values.reshape(-1,1)
Y = df.iloc[:,1]

# %% [markdown]
# ## EDA

# %%
df.isnull().sum()
# Out:
# Delivery Time    0
# Sorting Time     0
# dtype: int64

# %%
plt.boxplot(X)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x235ff22e490>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x235ff2251f0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x235ff22ef40>],
#  'medians': [<matplotlib.lines.Line2D at 0x235ff225f40>],
#  'fliers': [<matplotlib.lines.Line2D at 0x235ff217280>],
#  'means': []}

# %%
plt.boxplot(Y)  ## no outliers
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x235ff1da8b0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x235ff1dafd0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x235ff1da520>],
#  'medians': [<matplotlib.lines.Line2D at 0x235ff468730>],
#  'fliers': [<matplotlib.lines.Line2D at 0x235ff468ac0>],
#  'means': []}

# %%
df.describe()
# Out:
#        Delivery Time  Sorting Time
# count      21.000000     21.000000
# mean       16.790952      6.190476
# std         5.074901      2.542028
# min         8.000000      2.000000
# 25%        13.500000      4.000000
# 50%        17.830000      6.000000
# 75%        19.750000      8.000000
# max        29.000000     10.000000

# %% [markdown]
# ## Visualization

# %%
plt.scatter(df.iloc[ : , 0], df.iloc[ : , 1]);

plt.xlabel('Delievery Time');
plt.ylabel('Sorting Time');
plt.title("Delivery Time VS Sorting Time")
# Out:
# Text(0.5, 1.0, 'Delivery Time VS Sorting Time')

# %%
plt.scatter(df.iloc[ : , 0], df.iloc[ : , 1], color= "red");
plt.plot(df.iloc[ : , 0], df.iloc[ : , 1]);

plt.xlabel('Delievery Time');
plt.ylabel('Sorting Time');
plt.title("Delivery Time VS Sorting Time")
# Out:
# Text(0.5, 1.0, 'Delivery Time VS Sorting Time')

# %%
sns.distplot(df.iloc[ : , 0],label = 'Delivery Time');   ## distplot for Sorting time
plt.xlabel('Time');
plt.ylabel('Density');
plt.legend();
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
from sklearn.preprocessing import StandardScaler  # Z-scale(Standard scalar or standard method) values
sc = StandardScaler()
scale_data = sc.fit_transform(df)

# %%
scale_data
# Out:
# array([[ 0.84986692,  1.53562462],
#        [-0.66449036, -0.88298415],
#        [ 0.59747404, -0.07678123],
#        [ 1.45560983,  1.13252315],
#        [ 2.46518134,  1.53562462],
#        [-0.2909489 , -0.07678123],
#        [ 0.44603831,  0.32632023],
#        [-1.47214757, -1.28608562],
#        [ 0.22393258,  1.53562462],
#        [ 0.39555973,  1.13252315],
#        [ 0.61362718,  0.72942169],
#        [-1.21975469, -0.88298415],
#        [-0.02240287,  0.32632023],
#        [-1.06831896, -1.28608562],
#        [-0.96130438, -1.28608562],
#        [-0.38584862, -0.88298415],
#        [-0.61401178, -0.07678123],
#        [ 0.26633458,  0.32632023],
#        [-1.77501902, -1.68918708],
#        [ 0.20979858,  0.32632023],
#        [ 0.95082407, -0.47988269]])

# %%
sns.distplot(scale_data[ : , 1],label = 'Delivery Time');   ## distplot for Sorting time
plt.xlabel('Time');
plt.ylabel('Density');
plt.legend();
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
from sklearn import preprocessing  ##  narmalized data
import numpy as np

normalized = preprocessing.normalize(df)

# %%
sns.pairplot(df)

# %%
normalized
# Out:
# array([[0.90286052, 0.42993358],
#        [0.95879811, 0.28408833],
#        [0.95682044, 0.29067963],
#        [0.93632918, 0.35112344],
#        [0.94537298, 0.32599068],
#        [0.931377  , 0.36405616],
#        [0.93834312, 0.34570536],
#        [0.95358267, 0.30113137],
#        [0.87300456, 0.48771204],
#        [0.90152306, 0.43273107],
#        [0.92737605, 0.37413053],
#        [0.93722185, 0.34873371],
#        [0.92209259, 0.38696931],
#        [0.96761727, 0.2524219 ],
#        [0.97028467, 0.24196625],
#        [0.96571595, 0.25960106],
#        [0.91653938, 0.39994446],
#        [0.93274697, 0.36053168],
#        [0.9701425 , 0.24253563],
#        [0.93083396, 0.36544239],
#        [0.97400803, 0.22651349]])

# %%
sns.distplot(normalized[ : , 0],label = 'Delivery Time');   ## Graph for narmalized data
plt.xlabel('Time');
plt.ylabel('Density');
plt.legend();
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.bar(df.iloc[ : , 0],df.iloc[ : , 1],label = 'Sorting Time');   ## distplot for Sorting time
plt.xlabel('Delivery Time');
plt.ylabel('Sorting Time');
plt.legend();

# %%
sns.boxplot(x ="Delivery Time",y = "Sorting Time",data=df,color="red")
# Out:
# <AxesSubplot:xlabel='Delivery Time', ylabel='Sorting Time'>

# %%
sns.jointplot(x="Delivery Time", y = "Sorting Time", data= df )

# %%
sns.jointplot(x="Delivery Time", y = "Sorting Time", data= df, kind="kde" )

# %% [markdown]
# ## Transformation

# %%
from sklearn.preprocessing import StandardScaler  # Z-scale(Standard scalar or standard method) values
sc = StandardScaler()
scale_data = sc.fit_transform(df) 
scale_data
# Out:
# array([[ 0.84986692,  1.53562462],
#        [-0.66449036, -0.88298415],
#        [ 0.59747404, -0.07678123],
#        [ 1.45560983,  1.13252315],
#        [ 2.46518134,  1.53562462],
#        [-0.2909489 , -0.07678123],
#        [ 0.44603831,  0.32632023],
#        [-1.47214757, -1.28608562],
#        [ 0.22393258,  1.53562462],
#        [ 0.39555973,  1.13252315],
#        [ 0.61362718,  0.72942169],
#        [-1.21975469, -0.88298415],
#        [-0.02240287,  0.32632023],
#        [-1.06831896, -1.28608562],
#        [-0.96130438, -1.28608562],
#        [-0.38584862, -0.88298415],
#        [-0.61401178, -0.07678123],
#        [ 0.26633458,  0.32632023],
#        [-1.77501902, -1.68918708],
#        [ 0.20979858,  0.32632023],
#        [ 0.95082407, -0.47988269]])

# %%
from sklearn import preprocessing  ##  narmalized data
import numpy as np

normalized = preprocessing.normalize(df)

# %%
normalized
# Out:
# array([[0.90286052, 0.42993358],
#        [0.95879811, 0.28408833],
#        [0.95682044, 0.29067963],
#        [0.93632918, 0.35112344],
#        [0.94537298, 0.32599068],
#        [0.931377  , 0.36405616],
#        [0.93834312, 0.34570536],
#        [0.95358267, 0.30113137],
#        [0.87300456, 0.48771204],
#        [0.90152306, 0.43273107],
#        [0.92737605, 0.37413053],
#        [0.93722185, 0.34873371],
#        [0.92209259, 0.38696931],
#        [0.96761727, 0.2524219 ],
#        [0.97028467, 0.24196625],
#        [0.96571595, 0.25960106],
#        [0.91653938, 0.39994446],
#        [0.93274697, 0.36053168],
#        [0.9701425 , 0.24253563],
#        [0.93083396, 0.36544239],
#        [0.97400803, 0.22651349]])

# %% [markdown]
# ## Splitting dataset into training set and test set

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size =.25, random_state =1)

# %% [markdown]
# ## Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression    ##import linear regression library
model = LinearRegression() 
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
y = Y_train
Y_train = model.predict(X_train)
Y_pred = model.predict(X_test) ## predicting Y values for coressponding X values

# %%
plt.scatter(X_train,Y_train,color ="Red", label="Y_pred")
plt.plot(X_train,Y_train,color ="Green")
plt.scatter(X_train,y,color = "Blue", label ="Actual")
plt.title("Delivery_time Vs Sorting_Time")
plt.xlabel("Delivery_Time")
plt.ylabel("Sorting_Time")
plt.legend()

# %%
plt.scatter(X_test,Y_pred,color ="Red")
plt.plot(X_test,Y_pred,color ="Green", label = "Y_pred")
plt.scatter(X_test,Y_test,color = "Blue", label ="Actual")
plt.title("Delivery_time Vs Sorting_Time")
plt.xlabel("Delivery_Time")
plt.ylabel("Sorting_Time")
plt.legend()

# %% [markdown]
# # Accuracy or R^2 value

# %%
from sklearn.metrics import r2_score  # By using Rmse
print("Accuracy is : ", r2_score(Y_test,Y_pred) )
# Out:
# Accuracy is :  0.8354891504933364

# %% [markdown]
# ## Predict for new values

# %%
newdata = pd.Series([23,23.5])
data_pred = pd.DataFrame(newdata,columns =["DeliveryTime"])
model.predict(data_pred)
# Out:
# array([8.67506318, 8.86066351])
